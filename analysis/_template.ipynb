# %% [markdown]
# # Notebook title
#
# One-sentence description of what this notebook investigates.
#
# **Thesis:** Working hypothesis we'll test.
#
# **Data:** Which tables and date range.

# %%
"""Setup: shared utilities, connection, and check."""

# %load_ext autoreload
# %autoreload 2

from db import run_query, apply_plot_style

apply_plot_style()

# confirm the connection works.
run_query("SELECT COUNT(*) AS schedules_rows FROM schedules")
